# %% [markdown]
# <a href="https://colab.research.google.com/github/SandKrish/Data-Cleaning/blob/main/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f238ed81-5e2e-4f4b-8653-6be1964de8e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f238ed81-5e2e-4f4b-8653-6be1964de8e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("DataScience_Youtube_Videos.csv")

# %%
df.head(2)
# Out:
#                                          Video_Title  \
# 0  \n            \n            Data Science In 5 ...
# 1  \n            \n            What REALLY is Dat...
#
#                                     Video_Link Channel_Name  \
# 0  https://www.youtube.com/watch?v=X3paOmcrTjQ  Simplilearn
# 1  https://www.youtube.com/watch?v=xC-c7E5PK0Y    Joma Tech
#
#                                     Channel_Link Total_Views Publish_Date  \
# 0  https://www.youtube.com/c/SimplilearnOfficial  2.9M views  3 years ago
# 1             https://www.youtube.com/c/JomaOppa  3.1M views  4 years ago
#
#                                          Description
# 0  Boost your career with Simplilearn's 6-months ...
# 1  Interested in Data Science? Start with learnin...

# %%
df.shape
# Out:
# (173, 7)

# %%
df[df.duplicated()]
# Out:
#                                           Video_Title  \
# 65  \n            \n            Reality behind dat...
# 67  \n            \n            Coursera has an OF...
#
#                                      Video_Link Channel_Name  \
# 65   https://www.youtube.com/shorts/R6u5EBWAssY   codebasics
# 67  https://www.youtube.com/watch?v=y4yYTqjQHjM    Greg Hogg
#
#                             Channel_Link Total_Views  Publish_Date  \
# 65  https://www.youtube.com/c/codebasics  552K views  7 months ago
# 67    https://www.youtube.com/c/GregHogg  8.5K views  3 months ago
#
#                                           Description
# 65  Reality behind data science jobs. Is machine l...
# 67  The Pathway: Entry-Level Data Analyst ********...

# %%
df[df.duplicated(subset="Channel_Name")]
# Out:
#                                            Video_Title  \
# 11   \n            \n            How I Would Learn ...
# 12   \n            \n            🔥Data Science Full...
# 14   \n            \n            👩🏻‍💻 How to learn ...
# 15   \n            \n            Data Scientist vs ...
# 20   \n            \n            Should you become ...
# ..                                                 ...
# 161  \n            \n            6 Certifications I...
# 164  \n            \n            How to get a data ...
# 165  \n            \n            What Data Scientis...
# 166  \n            \n            4 CR+ SALARY for D...
# 172  \n            \n            Step by step roadm...
#
#                                       Video_Link           Channel_Name  \
# 11   https://www.youtube.com/watch?v=Rt6eb9VOFII      Recall by Dataiku
# 12   https://www.youtube.com/watch?v=xvEKQefqQ7A            Simplilearn
# 14   https://www.youtube.com/watch?v=lpSw_RAPmgc  Thu Vu data analytics
# ...

# %%
result_df = df.drop_duplicates(keep='first')

# %%
result_df.shape
# Out:
# (171, 7)

# %%
df[df.duplicated()]
# Out:
#                                           Video_Title  \
# 65  \n            \n            Reality behind dat...
# 67  \n            \n            Coursera has an OF...
#
#                                      Video_Link Channel_Name  \
# 65   https://www.youtube.com/shorts/R6u5EBWAssY   codebasics
# 67  https://www.youtube.com/watch?v=y4yYTqjQHjM    Greg Hogg
#
#                             Channel_Link Total_Views  Publish_Date  \
# 65  https://www.youtube.com/c/codebasics  552K views  7 months ago
# 67    https://www.youtube.com/c/GregHogg  8.5K views  3 months ago
#
#                                           Description
# 65  Reality behind data science jobs. Is machine l...
# 67  The Pathway: Entry-Level Data Analyst ********...

# %%
df[df['Video_Link']=='https://www.youtube.com/shorts/R6u5EBWAssY']
# Out:
#                                           Video_Title  \
# 18  \n            \n            Reality behind dat...
# 65  \n            \n            Reality behind dat...
#
#                                     Video_Link Channel_Name  \
# 18  https://www.youtube.com/shorts/R6u5EBWAssY   codebasics
# 65  https://www.youtube.com/shorts/R6u5EBWAssY   codebasics
#
#                             Channel_Link Total_Views  Publish_Date  \
# 18  https://www.youtube.com/c/codebasics  552K views  7 months ago
# 65  https://www.youtube.com/c/codebasics  552K views  7 months ago
#
#                                           Description
# 18  Reality behind data science jobs. Is machine l...
# 65  Reality behind data science jobs. Is machine l...

# %%
result_df[result_df['Video_Link']=='https://www.youtube.com/shorts/R6u5EBWAssY']
# Out:
#                                           Video_Title  \
# 18  \n            \n            Reality behind dat...
#
#                                     Video_Link Channel_Name  \
# 18  https://www.youtube.com/shorts/R6u5EBWAssY   codebasics
#
#                             Channel_Link Total_Views  Publish_Date  \
# 18  https://www.youtube.com/c/codebasics  552K views  7 months ago
#
#                                           Description
# 18  Reality behind data science jobs. Is machine l...

# %%
result_df[result_df['Video_Title'].str.contains('\n')]
# Out:
#                                            Video_Title  \
# 0    \n            \n            Data Science In 5 ...
# 1    \n            \n            What REALLY is Dat...
# 2    \n            \n            What is Data Scien...
# 3    \n            \n            These 6 Data Jobs ...
# 4    \n            \n            Top Courses to Lea...
# ..                                                 ...
# 168  \n            \n            Let's know about D...
# 169  \n            \n            A Complete Guide T...
# 170  \n            \n            Data Science Cours...
# 171  \n            \n            马大其实不难进？Universiti...
# 172  \n            \n            Step by step roadm...
#
#                                       Video_Link             Channel_Name  \
# 0    https://www.youtube.com/watch?v=X3paOmcrTjQ              Simplilearn
# 1    https://www.youtube.com/watch?v=xC-c7E5PK0Y                Joma Tech
# 2    https://www.youtube.com/watch?v=RBSUwFGa6Fk           IBM Technology
# ...

# %%
result_df = result_df.copy()

# %%
result_df['Video_Title'] = result_df['Video_Title'].replace(r'\n',' ', regex=True) 
result_df['Video_Title'].str.strip()
result_df.head(2)
# Out:
#                                          Video_Title  \
# 0                            Data Science In 5 Mi...
# 1                            What REALLY is Data ...
#
#                                     Video_Link Channel_Name  \
# 0  https://www.youtube.com/watch?v=X3paOmcrTjQ  Simplilearn
# 1  https://www.youtube.com/watch?v=xC-c7E5PK0Y    Joma Tech
#
#                                     Channel_Link Total_Views Publish_Date  \
# 0  https://www.youtube.com/c/SimplilearnOfficial  2.9M views  3 years ago
# 1             https://www.youtube.com/c/JomaOppa  3.1M views  4 years ago
#
#                                          Description
# 0  Boost your career with Simplilearn's 6-months ...
# 1  Interested in Data Science? Start with learnin...

# %%
display(result_df[result_df['Channel_Name'].str.contains('\n', na= False)])
display(result_df[result_df['Total_Views'].str.contains('\n', na = False)])
display(result_df[result_df['Publish_Date'].str.contains('\n', na = False)])
display(result_df[result_df['Description'].str.contains('\n', na = False)])
# Out:
# Empty DataFrame
# Columns: [Video_Title, Video_Link, Channel_Name, Channel_Link, Total_Views, Publish_Date, Description]
# Index: []
# Empty DataFrame
# Columns: [Video_Title, Video_Link, Channel_Name, Channel_Link, Total_Views, Publish_Date, Description]
# Index: []
# Empty DataFrame
# Columns: [Video_Title, Video_Link, Channel_Name, Channel_Link, Total_Views, Publish_Date, Description]
# Index: []
# Empty DataFrame
# Columns: [Video_Title, Video_Link, Channel_Name, Channel_Link, Total_Views, Publish_Date, Description]
# Index: []
